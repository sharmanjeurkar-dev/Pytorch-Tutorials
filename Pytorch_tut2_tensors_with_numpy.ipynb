# %%
import torch
import numpy as np

# %% [markdown]
# ### Tensor to Numpy Array

# %%
tensor = torch.arange(1,10)
tensor

# %%
nparray = tensor.numpy() # to convert a tensor to numpy 
nparray = nparray+1
tensor = tensor-1# change of tensor not applicable to nparray and vice versa
nparray,tensor

# %%
array = np.arange(1.0,10.0)
array

# %%
tensor_from_nparray = torch.from_numpy(array)
tensor_from_nparray

# %%
tensor_from_nparray =tensor_from_nparray+1
array =array-1#both are now independant
print(tensor_from_nparray)
print(array)
# Default dtype of nparray when given floating point values is float64. 
# But for tensors, the defult dtype is float32. Hence arrays need to be change to dtype float32
tensor_from_nparray.type(torch.float32)

# %% [markdown]
# ### Reproductivity of Random arrays
# To create random seed and need of Random seed

# %%
# When u want to create a random tensor, but want it to be same over ultiple execution and devices 
# use torch.manual_seed(seed = <number>)
RANDOM_SEED=42
torch.manual_seed(seed = RANDOM_SEED)
random_A = torch.rand(2,3)
#Refresh needed everytime to create 2 same tensors
RANDOM_SEED=42
torch.manual_seed(seed = RANDOM_SEED)
random_B = torch.rand(2,3)
print(random_A)
print(random_B)
random_A == random_B
